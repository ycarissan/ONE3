# %% [markdown]
# # Évaluation
#
# ---
#
# ## Introduction
#
# Cette évaluation a pour but de déterminer si vous avez acquis les bases de programmation que nous avons vues ensemble.
# Vous avez accès à internet ce qui vous permet de consulter les sites de documentation si nécessaire.
#
# L'utilisation de l'IA sous quelque forme que ce soit est interdite. Les putils de détection de l'IA sont activés.
#
# Une fois l'évaluation terminée, déposer le fichier au format ipynb sur ametice.
#
# ---
#
# ## Tracé de courbes 1D
# 1. Tracer la fonction $f(x) = x^3$ sur l'intervalle $[-2; 3]$. À l'aide de **`scipy.integrate.quad`** intégrer cette fonction sur [-0.5; 1] et afficher l'aire sous la courbe correspondant à cette intégrale. Ajnouter une légende et mettre en évidence l'intervalle d'intégration avec des traits verticaux.
# 2. Même travail pour la fonction $g(x) = e^{-x}$ tracée sur $[-1; 1]$ et intégrée sur $[-0.5; 0.5]$.
# 3. Même travail pour la fonction $h(x) = cos(x)$ tracée sur $[-2\pi; 2\pi]$ et intégrée sur $[-\pi; \pi]$.
# ---

# %%
#Votre code ici

# %% [markdown]
# ## Fonctions radiales des orbitales atomiques et densité de probabilité radiale
#
# Les fonctions radiales décrivent la variation des orbitales atomiques en fonction de la distance $r$ au noyau. Voici les expressions analytiques des fonctions étudiées :
# - $R_{10}(r)$ : Fonction radiale de l'orbitale 1s
#
# $$R_{10}(r) = \left(\frac{1}{a_0}\right)^{\frac{3}{2}} \times 2 \exp(-\frac{r}{a_0})$$
#
# La densité de probabilité radiale est définie comme :
# $$
# P_{nl}(r) = r^2 |R_{nl}(r)|^2
# $$
#
# Pour la fonction $1s$ (n=1, l=0) alculer la probabilité de présence dans l'intervalle $[0;2]$, $[3;5]$ et $[4;6]$.

# %%
#Votre code ici
